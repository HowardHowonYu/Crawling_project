# %%
df = pd.read_csv("EPL.csv")

# %%
df[['club_name','position','points','won','drawn','lost','ga','gd','gf','player']]
# Out:
#                    club_name  position  points  won  drawn  lost  ga  gd  gf  \
# 0                  Liverpool         1      79   26      1     1  20  44  64
# 1            Manchester City         2      57   18      3     6  29  39  68
# 2             Leicester City         3      50   15      5     8  28  26  54
# 3                    Chelsea         4      45   13      6     9  39   8  47
# 4          Manchester United         5      42   11      9     8  30  12  42
# 5    Wolverhampton Wanderers         6      42   10     12     6  34   7  41
# 6          Tottenham Hotspur         7      40   11      7    10  39   7  46
# 7           Sheffield United         8      40   10     10     7  25   4  29
# 8                    Burnley         9      38   11      5    12  39  -6  33
# 9                    Arsenal        10      37    8     13     6  36   3  39
# 10                   Everton        11      37   10      7    11  42  -5  37
# ...
